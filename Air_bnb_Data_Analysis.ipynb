# %%
# !pip install pymongo
# Out:
# Collecting pymongo
#   Obtaining dependency information for pymongo from https://files.pythonhosted.org/packages/c8/1a/1ba5578cc3acc8ef0dfd6eb9385f9c4b0fe3039665af93bcf062c34fcdb6/pymongo-4.6.1-cp311-cp311-win_amd64.whl.metadata
#   Downloading pymongo-4.6.1-cp311-cp311-win_amd64.whl.metadata (22 kB)
# Collecting dnspython<3.0.0,>=1.16.0 (from pymongo)
#   Obtaining dependency information for dnspython<3.0.0,>=1.16.0 from https://files.pythonhosted.org/packages/f6/b4/0a9bee52c50f226a3cbfb54263d02bb421c7f2adc136520729c2c689c1e5/dnspython-2.4.2-py3-none-any.whl.metadata
#   Downloading dnspython-2.4.2-py3-none-any.whl.metadata (4.9 kB)
# Downloading pymongo-4.6.1-cp311-cp311-win_amd64.whl (472 kB)
#    ---------------------------------------- 0.0/472.7 kB ? eta -:--:--
#    --- ----------------------------------- 41.0/472.7 kB 653.6 kB/s eta 0:00:01
#    ------- -------------------------------- 92.2/472.7 kB 1.1 MB/s eta 0:00:01
#    ------------ --------------------------- 153.6/472.7 kB 1.0 MB/s eta 0:00:01
#    ------------------- -------------------- 235.5/472.7 kB 1.2 MB/s eta 0:00:01
#    -------------------------- ------------- 317.4/472.7 kB 1.4 MB/s eta 0:00:01
#    -------------------------------------- - 450.6/472.7 kB 1.6 MB/s eta 0:00:01
#    ---------------------------------------- 472.7/472.7 kB 1.5 MB/s eta 0:00:00
# Downloading dnspython-2.4.2-py3-none-any.whl (300 kB)
#    ---------------------------------------- 0.0/300.4 kB ? eta -:--:--
#    ------------ --------------------------- 92.2/300.4 kB 2.6 MB/s eta 0:00:01
#    --------------------------- ------------ 204.8/300.4 kB 2.5 MB/s eta 0:00:01
#    ---------------------------------------- 300.4/300.4 kB 2.3 MB/s eta 0:00:00
# Installing collected packages: dnspython, pymongo
# Successfully installed dnspython-2.4.2 pymongo-4.6.1

# %%
import pymongo
import pandas as pd

# %%
my_mongodb_connection = pymongo.MongoClient('mongodb+srv://prakash_96:indian@cluster0.z8dxvkx.mongodb.net/')
my_mongo_database = my_mongodb_connection['sample_airbnb']

# %%
db = my_mongodb_connection['sample_airbnb']

# %%
db.list_collection_names()
# Out:
# ['listingsAndReviews']

# %%
col = db['listingsAndReviews']

# %%
# Required Data Extraction

data = col.find()

data_list = []

for i in data:
    id = i['_id']
    url = i['listing_url']
    name = i['name']
    description = i['description']
    host_id  = i['host']['host_id']
    host_name = i['host']['host_name']
    neighborhood_overview = i['neighborhood_overview']
    location = i['address']['location']['coordinates']
    country = i['address']['country']
    city = i['address']['market']
    price = i['price']
    availability_30 = i['availability']['availability_30']
    availability_60 = i['availability']['availability_60']
    availability_90 = i['availability']['availability_90']
    availability_365 = i['availability']['availability_365']
    amenities = i['amenities']
    review_scores_value = i.get('review_scores', {}).get('review_scores_value', None)
    no_of_reviews = i['number_of_reviews']
    
    row_data = [id,url,name,description,host_id,host_name,neighborhood_overview,location,country,city,price,availability_30,availability_60,availability_90,availability_365,amenities,no_of_reviews,review_scores_value]
    data_list.append(row_data)

# %%
df = pd.DataFrame(data_list,columns = ['id','url','name','description','host_id','host_name','neighborhood_overview','location','country','city','price','availability_30','availability_60','availability_90','availability_365','amenities','no_of_reviews','review_score'])
df
# Out:
#             id                                    url  \
# 0     10006546  https://www.airbnb.com/rooms/10006546
# 1     10009999  https://www.airbnb.com/rooms/10009999
# 2      1001265   https://www.airbnb.com/rooms/1001265
# 3     10021707  https://www.airbnb.com/rooms/10021707
# 4     10030955  https://www.airbnb.com/rooms/10030955
# ...        ...                                    ...
# 5550   9983221   https://www.airbnb.com/rooms/9983221
# 5551   9985696   https://www.airbnb.com/rooms/9985696
# 5552   9987200   https://www.airbnb.com/rooms/9987200
# 5553   9990304   https://www.airbnb.com/rooms/9990304
# 5554   9993190   https://www.airbnb.com/rooms/9993190
#
#                                                    name  \
# 0                               Ribeira Charming Duplex
# 1                          Horto flat with small garden
# 2                      Ocean View Waikiki Marina w/prkg
# 3                              Private Room in Bushwick
# 4                           Apt Linda Vista Lagoa - Rio
# ...                                                 ...
# 5550                      Cozy apartment downtown Porto
# 5551                                    Kadıköy-Altıyol
# 5552       The best suite in Copacabana (total privacy)
# 5553     March Madness Special! Aina Nalu Platinum D107
# 5554  Just Steps from the Ocean at Premier Platinum ...
#
#                                             description   host_id  \
# 0     Fantastic duplex apartment with three bedrooms...  51399391
# 1     One bedroom + sofa-bed in quiet and bucolic ne...   1282196
# 2     A short distance from Honolulu's billion dolla...   5448114
# 3     Here exists a very cozy room for rent in a sha...  11275734
# 4     Quarto com vista para a Lagoa Rodrigo de Freit...  51496939
# ...                                                 ...       ...
# 5550  Renovated, fully equipped, within walking dist...  37776205
# 5551  Kadıköy merkezde 2+1 dairem vardır.Çok kalabal...  51303748
# 5552  Excellent private suite with bathroom at the A...  51314789
# 5553  Walk out to Saltwater Infinity Pool! Call us N...  51013381
# 5554  Relax Hawaiian Style in Gated Community on Oce...  51013381
#
#            host_name                              neighborhood_overview  \
# 0        Ana&Gonçalo  In the neighborhood of the river, you can find...
# 1              Ynaie  This charming ground floor flat is located in ...
# 2              David             You can breath ocean as well as aloha.
# 3               Josh
# 4              Livia
# ...              ...                                                ...
# 5550             Ana  Just in the street 50 meters from the apartmen...
# 5551            Eren
# 5552          Dumont  Copacabana beach is located in a district of t...
# 5553  Coconut Condos  -Located in the heart of Lahaina town and a sh...
# 5554  Coconut Condos  Location: Located at the south end of Lahaina ...
#
#                                         location        country  \
# 0                            [-8.61308, 41.1413]       Portugal
# 1      [-43.23074991429229, -22.966253551739655]         Brazil
# 2                         [-157.83919, 21.28634]  United States
# 3                          [-73.93615, 40.69791]  United States
# 4     [-43.205047082633435, -22.971950988341874]         Brazil
# ...                                          ...            ...
# 5550                        [-8.61693, 41.15137]       Portugal
# 5551                        [29.03079, 40.98563]         Turkey
# 5552   [-43.17653326486353, -22.961076366204612]         Brazil
# 5553                      [-156.67646, 20.87561]  United States
# 5554                      [-156.66752, 20.85894]  United States
#
#                 city   price  availability_30  availability_60  \
# 0              Porto   80.00               28               47
# 1     Rio De Janeiro  317.00                0                0
# 2               Oahu  115.00               16               46
# 3           New York   40.00                0                0
# 4     Rio De Janeiro  701.00               28               58
# ...              ...     ...              ...              ...
# 5550           Porto   58.00               26               51
# 5551        Istanbul  501.00               30               60
# 5552  Rio De Janeiro  101.00                7               29
# 5553            Maui  227.00                8               20
# 5554            Maui  220.00                0                8
#
#       availability_90  availability_365  \
# 0                  74               239
# 1                   0                 0
# 2                  76               343
# 3                   0                 0
# 4                  88               363
# ...               ...               ...
# 5550               77               300
# 5551               90               365
# 5552               53                53
# 5553               26               243
# 5554               31               258
#
#                                               amenities  no_of_reviews  \
# 0     [TV, Cable TV, Wifi, Kitchen, Paid parking off...             51
# 1     [Wifi, Wheelchair accessible, Kitchen, Free pa...              0
# 2     [TV, Cable TV, Wifi, Air conditioning, Pool, K...             96
# 3     [Internet, Wifi, Air conditioning, Kitchen, Bu...              1
# 4     [TV, Cable TV, Internet, Wifi, Air conditionin...              0
# ...                                                 ...            ...
# 5550  [TV, Cable TV, Internet, Wifi, Kitchen, Paid p...            107
# 5551  [TV, Cable TV, Internet, Wifi, Kitchen, Buzzer...              0
# 5552  [TV, Cable TV, Wifi, Air conditioning, Pool, G...             90
# 5553  [TV, Cable TV, Wifi, Air conditioning, Wheelch...             13
# 5554  [TV, Wifi, Air conditioning, Pool, Kitchen, Fr...             15
#
#       review_score
# 0              9.0
# 1              NaN
# 2              9.0
# 3              8.0
# 4              NaN
# ...            ...
# 5550          10.0
# 5551           NaN
# 5552           9.0
# 5553           9.0
# 5554           9.0
#
# [5555 rows x 18 columns]

# %%
df['latitude'] = df['location'].apply(lambda x:x[1])
df['longitude'] = df['location'].apply(lambda x:x[0])

# %%
df.drop('location',axis = 1,inplace=True)

# %%
df.sample(5)
# Out:
#             id                                    url  \
# 9     10057447  https://www.airbnb.com/rooms/10057447
# 4515   3885090   https://www.airbnb.com/rooms/3885090
# 4314  32214610  https://www.airbnb.com/rooms/32214610
# 3971  30531901  https://www.airbnb.com/rooms/30531901
# 1959  20286842  https://www.airbnb.com/rooms/20286842
#
#                                              name  \
# 9                  Modern Spacious 1 Bedroom Loft
# 4515  Cozy Cabin w/Sauna & Lomilomi - Steps to UH
# 4314     Apartamento Miami - Francelos  V.N. Gaia
# 3971    Apartamento Aconchegante Próximo ao Metrô
# 1959                           Tootsie's Hideaway
#
#                                             description    host_id  \
# 9     Prime location, amazing lighting and no annoyi...   51612949
# 4515  Private guest cottage that sleeps 6 people. Lu...    7324234
# 4314  localizada num condomínio calmo e tranquilo. C...  241735685
# 3971  O apartamento fica a 3 quadras da Praia do Fla...  229100069
# 1959  Secluded & charming, Tootsie's Hideaway is nes...    9951576
#
#               host_name                              neighborhood_overview  \
# 9            Konstantin
# 4515        Karen Lucky  This is an older, upscale neighborhood, next t...
# 4314               Jose
# 3971              Maria
# 1959  Marie Fellenstein  Upcountry Waimea (Kamuela on Hawaii Island, th...
#
#             country            city   price  availability_30  availability_60  \
# 9            Canada        Montreal   50.00                0                0
# 4515  United States            Oahu  165.00               27               57
# 4314       Portugal           Porto   75.00               30               60
# 3971         Brazil  Rio De Janeiro  216.00                0               27
# 1959  United States  The Big Island   80.00                9               36
#
#       availability_90  availability_365  \
# 9                   0                 0
# 4515               87               362
# 4314               90               186
# 3971               46                46
# 1959               60               145
#
#                                               amenities  no_of_reviews  \
# 9     [Internet, Wifi, Kitchen, Heating, Family/kid ...              0
# 4515  [Internet, Wifi, Kitchen, Free parking on prem...            115
# 4314  [TV, Wifi, Pool, Kitchen, Free parking on prem...              0
# 3971  [TV, Wifi, Air conditioning, Kitchen, Elevator...              2
# 1959  [Wifi, Free parking on premises, Free street p...             37
#
#       review_score   latitude   longitude
# 9              NaN  45.518890  -73.591110
# 4515           9.0  21.307340 -157.813750
# 4314           NaN  41.080290   -8.645760
# 3971          10.0 -22.934893  -43.177366
# 1959          10.0  20.026240 -155.677520

# %%
df.dtypes
# Out:
# id                        object
# url                       object
# name                      object
# description               object
# host_id                   object
# host_name                 object
# neighborhood_overview     object
# country                   object
# city                      object
# price                     object
# availability_30            int64
# availability_60            int64
# availability_90            int64
# availability_365           int64
# amenities                 object
# no_of_reviews              int64
# review_score             float64
# latitude                 float64
# longitude                float64
# dtype: object

# %%
df.shape
# Out:
# (5555, 19)

# %%
df.isnull().sum()
# Out:
# id                       0
# url                      0
# name                     0
# description              0
# host_id                  0
# host_name                0
# neighborhood_overview    0
# country                  0
# city                     0
# price                    0
# availability_30          0
# availability_60          0
# availability_90          0
# availability_365         0
# amenities                0
# no_of_reviews            0
# review_score             0
# latitude                 0
# longitude                0
# dtype: int64

# %%
# Dropping the null values
df.dropna(inplace = True)

# %%
# Exporting the data
df.to_csv('airbnb_dataset.csv')
